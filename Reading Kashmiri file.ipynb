# %% [markdown]
# ##Reading Kashmiri file

# %%
File = open("t1.xml",encoding = "utf-8")
print(File.read())
# Out:
# <?xml-stylesheet type="text/css" href="home.css"?><Doc id="kas-w-media-KS00001" lang="Kashmiri"><Header type="text"><encodingDesc><projectDesc>CIIL-LDCIL Kashmiri Corpora, Monolingual Written Text</projectDesc><samplingDesc>Simple written text only has been transcribed. Diagrams, pictures, tables and verses have been omitted. Samples taken from page 30-33,60-63,90-93,121-123,152-155,180-183,210-213,240-243,270-273,298-299 </samplingDesc></encodingDesc><sourceDesc><biblStruct><source>Personal Library Mr. Masroor Ahmed Mir <category>Aesthetics</category><subcategory>Literature-Novels</subcategory><text>Book</text><title>مُجرِم</title><vol /><issue /></source><textDesc><type /><headline /><author>Gulam Nabi Gohar</author><editor /><translator /><words>5897</words><letters>0</letters></textDesc><imprint><pubPlace>Jammu and Kashmir</pubPlace><publisher>shehul publications</publisher><pubDate>01-Jul-2013</pubDate></imprint><idno type="CIIL code" /><index>KS00001</index></biblStruct></sourc
# ...
